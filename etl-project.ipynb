# %% [markdown]
# # ETL of Dow 30 Stock Data
# #### Fabienne Zumbuehl; James Ye; Tanvir Khan

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
from splinter import Browser
import time
from sqlalchemy import create_engine

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## price data from cnbc.com

# %%
price_url = "https://www.cnbc.com/dow-30/"

# %%
browser.visit(price_url)
time.sleep(5)
price_html = browser.html

# %%
price_data_tables = pd.read_html(price_html)
print("Number of tables: ", len(price_data_tables))
price_data_df = price_data_tables[0]
#price_data_df.set_index('id', inplace=True)

# drop ticker 'Dow' because their substainability can not be found in Yahoo Finance
price_data_df.drop(index=29, inplace=True)

price_data_df = price_data_df[["SYMBOL","NAME", "PRICE", "LOW", "HIGH", "PREVIOUS CLOSE"]].copy()
price_data_df.rename(columns = {"SYMBOL":"symbol","NAME":"company", "PRICE":"price", "LOW":"low", "HIGH":"high", "PREVIOUS CLOSE":"previous_close"}, inplace=True)
price_data_df
# Out:
# Number of tables:  1
#    symbol                               company   price      low     high  \
# 0     AXP                   American Express Co   89.83   89.125   91.430
# 1    AAPL                             Apple Inc  316.85  315.870  320.890
# 2      BA                             Boeing Co  139.00  136.151  144.239
# 3     CAT                       Caterpillar Inc  114.06  113.820  115.680
# 4    CSCO                     Cisco Systems Inc   44.64   44.555   45.655
# 5     CVX                          Chevron Corp   92.04   91.280   93.370
# 6     XOM                      Exxon Mobil Corp   44.56   44.390   45.790
# 7      GS               Goldman Sachs Group Inc  180.10  177.680  181.170
# 8      HD                        Home Depot Inc  240.88  235.790  241.180
# 9     IBM  International Business Machines Corp  119.12  118.970  121.720
# 10   INTC                            Intel Corp   61.98   61.820   63.800
# 11    JNJ                     Johnson & Johnson  146.71  145.820  148.500
# 12     KO                          Coca-Cola Co   45.17   45.030   46.090
# 13    JPM                   JPMorgan Chase & Co   90.17   89.670   91.760
# 14    MCD                       McDonald’s Corp  185.08  182.106  185.480
# 15    MMM                                 3M Co  145.81  145.340  148.640
# 16    MRK                        Merck & Co Inc   76.55   76.270   77.030
# 17   MSFT                        Microsoft Corp  183.43  183.290  186.670
# 18    NKE                              Nike Inc   94.26   92.370   94.380
# 19    PFE                            Pfizer Inc   37.26   37.050   37.650
# 20     PG                   Procter & Gamble Co  111.62  111.430  113.200
# 21    TRV               Travelers Companies Inc   99.17   94.930  100.800
# 22    UNH                UnitedHealth Group Inc  286.91  284.930  290.130
# 23    RTX            Raytheon Technologies Corp   60.10   58.200   60.210
# 24     VZ            Verizon Communications Inc   53.97   53.860   54.640
# 25      V                              Visa Inc  190.62  190.020  193.616
# 26    WBA          Walgreens Boots Alliance Inc   39.75   39.660   40.760
# 27    WMT                           Walmart Inc  124.99  124.250  126.140
# 28    DIS                        Walt Disney Co  117.83  116.500  120.300
#
#     previous_close
# 0            89.83
# 1           316.85
# 2           139.00
# 3           114.06
# 4            44.64
# 5            92.04
# 6            44.56
# 7           180.10
# 8           240.88
# 9           119.12
# 10           61.98
# 11          145.70
# 12           45.17
# 13           90.17
# 14          185.08
# 15          145.81
# 16           76.55
# 17          183.43
# 18           94.26
# 19           37.26
# 20          111.62
# 21           99.17
# 22          286.91
# 23           60.10
# 24           53.97
# 25          190.62
# 26           39.75
# 27          124.99
# 28          117.83

# %%
dow29_symbols = price_data_df["symbol"]
type(dow29_symbols)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## dividend data from dividend.com

# %%
dividend_url = "https://www.dividend.com/dividend-stocks/dow-30-dividend-stocks/"

# %%
dividend_data_tables = pd.read_html(dividend_url)
print("Number of tables: ", len(dividend_data_tables))
dividend_data_df = dividend_data_tables[0]
dividend_data_df.head()
# Out:
# Number of tables:  1
#    Unnamed: 0 Stock Symbol         Company Name DARSâ¢ Rating Dividend Yield  \
# 0         NaN          XOM          Exxon Mobil         locked          7.87%
# 1         NaN           BA           Boeing Co.         locked          6.16%
# 2         NaN          CVX         Chevron Corp         locked          5.40%
# 3         NaN          IBM             IBM Corp         locked          5.30%
# 4         NaN          UTX  United Technologies         locked          5.16%
#
#   Closing Price Annualized Dividend Ex-Div Date    Pay Date
# 0        $45.74             $3.4800  2020-05-12  2020-06-10
# 1       $128.91             $8.2200  2020-02-13  2020-03-06
# 2        $93.37             $5.1600  2020-05-18  2020-06-10
# 3       $122.59             $6.5200  2020-05-07  2020-06-10
# 4        $86.01             $2.9400  2020-02-13  2020-03-10

# %%
# only run these once!!!
del(dividend_data_df["Unnamed: 0"])
#dividend_data_df.set_index("Stock Symbol", inplace=True)
dividend_data_df.head()
# Out:
#   Stock Symbol         Company Name DARSâ¢ Rating Dividend Yield  \
# 0          XOM          Exxon Mobil         locked          7.87%
# 1           BA           Boeing Co.         locked          6.16%
# 2          CVX         Chevron Corp         locked          5.40%
# 3          IBM             IBM Corp         locked          5.30%
# 4          UTX  United Technologies         locked          5.16%
#
#   Closing Price Annualized Dividend Ex-Div Date    Pay Date
# 0        $45.74             $3.4800  2020-05-12  2020-06-10
# 1       $128.91             $8.2200  2020-02-13  2020-03-06
# 2        $93.37             $5.1600  2020-05-18  2020-06-10
# 3       $122.59             $6.5200  2020-05-07  2020-06-10
# 4        $86.01             $2.9400  2020-02-13  2020-03-10

# %%
dividend_reduced_df = dividend_data_df[['Stock Symbol', 'Dividend Yield', 'Annualized Dividend', 'Ex-Div Date', 'Pay Date']].copy()
#dividend_reduced_df.index.name = "SYMBOL"
#dividend_reduced_df.drop(index=29, inplace=True)
dividend_df = dividend_reduced_df
# dividend_df.index.name = 'id'
dividend_df
# Out:
#    Stock Symbol Dividend Yield Annualized Dividend Ex-Div Date    Pay Date
# 0           XOM          7.87%             $3.4800  2020-05-12  2020-06-10
# 1            BA          6.16%             $8.2200  2020-02-13  2020-03-06
# 2           CVX          5.40%             $5.1600  2020-05-18  2020-06-10
# 3           IBM          5.30%             $6.5200  2020-05-07  2020-06-10
# 4           UTX          5.16%             $2.9400  2020-02-13  2020-03-10
# 5           WBA          4.50%             $1.8300  2020-05-19  2020-06-12
# 6           PFE          4.11%             $1.5200  2020-05-07  2020-06-05
# 7           MMM          4.03%             $5.8800  2020-02-13  2020-03-12
# 8           JPM          3.95%             $3.6000  2020-04-03  2020-04-30
# 9            KO          3.68%             $1.6400  2020-06-12  2020-07-01
# 10          CAT          3.67%             $4.1200  2020-04-17  2020-05-20
# 11          TRV          3.55%             $3.4000  2020-06-09  2020-06-30
# 12         CSCO          3.35%             $1.4400  2020-04-02  2020-04-22
# 13          MRK          3.23%             $2.4400  2020-03-13  2020-04-07
# 14           PG          2.82%             $3.1628  2020-04-23  2020-05-15
# 15          MCD          2.76%             $5.0000  2020-02-28  2020-03-16
# 16          JNJ          2.74%             $4.0400  2020-05-22  2020-06-09
# 17           GS          2.70%             $5.0000  2020-05-29  2020-06-29
# 18           HD          2.56%             $6.0000  2020-03-11  2020-03-26
# 19         INTC          2.21%             $1.3200  2020-05-06  2020-06-01
# 20          AXP          1.92%             $1.7200  2020-07-01  2020-08-10
# 21          WMT          1.77%             $2.1600  2020-08-13  2020-09-08
# 22          DIS          1.61%             $1.7600  2019-12-13  2020-01-16
# 23          UNH          1.52%             $4.3200  2020-03-13  2020-03-24
# 24         MSFT          1.11%             $2.0400  2020-05-20  2020-06-11
# 25          NKE          1.11%             $0.9800  2020-05-29  2020-07-01
# 26         AAPL          1.06%             $3.2800  2020-05-08  2020-05-14
# 27            V          0.66%             $1.2000  2020-05-13  2020-06-02
# 28         DWDP          0.00%             $0.0000         NaN         NaN

# %%
dividend_df['Dividend Yield'] = dividend_df['Dividend Yield'].str.replace('%','').astype(float)
dividend_df['Annualized Dividend'] = dividend_df['Annualized Dividend'].str.replace('$','').astype(float)

# %%
print(dividend_df.dtypes)

dividend_df.rename(columns = {"Stock Symbol":"symbol", "Dividend Yield": "dividend_yield", "Annualized Dividend":"annualized_dividend", "Ex-Div Date":"ex_div_date", "Pay Date":"pay_date"}, inplace=True)


dividend_df.head()
# Out:
# symbol                  object
# dividend_yield         float64
# Annualized Dividend    float64
# ex_div_date             object
# pay_date                object
# dtype: object
#   symbol  dividend_yield  annualized_dividend ex_div_date    pay_date
# 0    XOM            7.87                 3.48  2020-05-12  2020-06-10
# 1     BA            6.16                 8.22  2020-02-13  2020-03-06
# 2    CVX            5.40                 5.16  2020-05-18  2020-06-10
# 3    IBM            5.30                 6.52  2020-05-07  2020-06-10
# 4    UTX            5.16                 2.94  2020-02-13  2020-03-10

# %% [markdown]
# ## finance.yahoo.com

# %%
print("ticker", "ESG Score")
egs_rating_list = []
first = True
for stock_symbol in dow29_symbols:
    sustainability_url = f"https://finance.yahoo.com/quote/{stock_symbol}/sustainability?p={stock_symbol}"
    browser.visit(sustainability_url)
    if first:
        time.sleep(5)
        first = False
    else:
        time.sleep(1)
    ESG_Risk_Score = browser.find_by_css('div[class="Fz(36px) Fw(600) D(ib) Mend(5px)"]').value
    print(stock_symbol, ESG_Risk_Score)
    egs_rating_list.append(ESG_Risk_Score)
# Out:
# ticker ESG Score
# AXP 22
# AAPL 24
# BA 39
# CAT 38
# CSCO 14
# CVX 40
# XOM 34
# GS 32
# HD 13
# IBM 18
# INTC 16
# JNJ 35
# KO 26
# JPM 22
# MCD 25
# MMM 34
# MRK 28
# MSFT 16
# NKE 17
# PFE 33
# PG 25
# TRV 24
# UNH 21
# RTX 29
# VZ 20
# V 18
# WBA 17
# WMT 29
# DIS 15

# %%
egs_rating_list
# Out:
# ['22',
#  '24',
#  '39',
#  '38',
#  '14',
#  '40',
#  '34',
#  '32',
#  '13',
#  '18',
#  '16',
#  '35',
#  '26',
#  '22',
#  '25',
#  '34',
#  '28',
#  '16',
#  '17',
#  '33',
#  '25',
#  '24',
#  '21',
#  '29',
#  '20',
#  '18',
#  '17',
#  '29',
#  '15']

# %%
price_data_df['esg_rating'] = egs_rating_list

# %%
price_data_df['esg_rating'] = pd.to_numeric(price_data_df['esg_rating'])
#price_data_df.rename(columns={'%CHANGE':'PCT_CHANGE'}, inplace=True)
#price_data_df['NAME'] = price_data_df['NAME'].astype(str)
price_data_df.dtypes
# Out:
# symbol             object
# company            object
# price             float64
# low               float64
# high              float64
# previous_close    float64
# esg_rating          int64
# dtype: object

# %%
price_data_df
# Out:
#    symbol                               company   price      low     high  \
# 0     AXP                   American Express Co   89.83   89.125   91.430
# 1    AAPL                             Apple Inc  316.85  315.870  320.890
# 2      BA                             Boeing Co  139.00  136.151  144.239
# 3     CAT                       Caterpillar Inc  114.06  113.820  115.680
# 4    CSCO                     Cisco Systems Inc   44.64   44.555   45.655
# 5     CVX                          Chevron Corp   92.04   91.280   93.370
# 6     XOM                      Exxon Mobil Corp   44.56   44.390   45.790
# 7      GS               Goldman Sachs Group Inc  180.10  177.680  181.170
# 8      HD                        Home Depot Inc  240.88  235.790  241.180
# 9     IBM  International Business Machines Corp  119.12  118.970  121.720
# 10   INTC                            Intel Corp   61.98   61.820   63.800
# 11    JNJ                     Johnson & Johnson  146.71  145.820  148.500
# 12     KO                          Coca-Cola Co   45.17   45.030   46.090
# 13    JPM                   JPMorgan Chase & Co   90.17   89.670   91.760
# 14    MCD                       McDonald’s Corp  185.08  182.106  185.480
# 15    MMM                                 3M Co  145.81  145.340  148.640
# 16    MRK                        Merck & Co Inc   76.55   76.270   77.030
# 17   MSFT                        Microsoft Corp  183.43  183.290  186.670
# 18    NKE                              Nike Inc   94.26   92.370   94.380
# 19    PFE                            Pfizer Inc   37.26   37.050   37.650
# 20     PG                   Procter & Gamble Co  111.62  111.430  113.200
# 21    TRV               Travelers Companies Inc   99.17   94.930  100.800
# 22    UNH                UnitedHealth Group Inc  286.91  284.930  290.130
# 23    RTX            Raytheon Technologies Corp   60.10   58.200   60.210
# 24     VZ            Verizon Communications Inc   53.97   53.860   54.640
# 25      V                              Visa Inc  190.62  190.020  193.616
# 26    WBA          Walgreens Boots Alliance Inc   39.75   39.660   40.760
# 27    WMT                           Walmart Inc  124.99  124.250  126.140
# 28    DIS                        Walt Disney Co  117.83  116.500  120.300
#
#     previous_close  esg_rating
# 0            89.83          22
# 1           316.85          24
# 2           139.00          39
# 3           114.06          38
# 4            44.64          14
# 5            92.04          40
# 6            44.56          34
# 7           180.10          32
# 8           240.88          13
# 9           119.12          18
# 10           61.98          16
# 11          145.70          35
# 12           45.17          26
# 13           90.17          22
# 14          185.08          25
# 15          145.81          34
# 16           76.55          28
# 17          183.43          16
# 18           94.26          17
# 19           37.26          33
# 20          111.62          25
# 21           99.17          24
# 22          286.91          21
# 23           60.10          29
# 24           53.97          20
# 25          190.62          18
# 26           39.75          17
# 27          124.99          29
# 28          117.83          15

# %% [markdown]
# # load data into database

# %%
connection_string = "postgres:postgres@localhost:5432/stock_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['price_data_df', 'dividend_df']

# %%
#price_data_df.columns = [["symbol", "company", "price", "low", "high", "previous_close","esg_rating" ]]
print(price_data_df.dtypes)

price_data_df.head()
# Out:
# symbol             object
# company            object
# price             float64
# low               float64
# high              float64
# previous_close    float64
# esg_rating          int64
# dtype: object
#   symbol              company   price      low     high  previous_close  \
# 0    AXP  American Express Co   89.83   89.125   91.430           89.83
# 1   AAPL            Apple Inc  316.85  315.870  320.890          316.85
# 2     BA            Boeing Co  139.00  136.151  144.239          139.00
# 3    CAT      Caterpillar Inc  114.06  113.820  115.680          114.06
# 4   CSCO    Cisco Systems Inc   44.64   44.555   45.655           44.64
#
#    esg_rating
# 0          22
# 1          24
# 2          39
# 3          38
# 4          14

# %%
price_data_df.to_sql(name='price_data_df', con=engine, if_exists='append', index=False)

# %%
print(dividend_df.dtypes)

dividend_df.head()
# Out:
# symbol                  object
# dividend_yield         float64
# annualized_dividend    float64
# ex_div_date             object
# pay_date                object
# dtype: object
#   symbol  dividend_yield  annualized_dividend ex_div_date    pay_date
# 0    XOM            7.87                 3.48  2020-05-12  2020-06-10
# 1     BA            6.16                 8.22  2020-02-13  2020-03-06
# 2    CVX            5.40                 5.16  2020-05-18  2020-06-10
# 3    IBM            5.30                 6.52  2020-05-07  2020-06-10
# 4    UTX            5.16                 2.94  2020-02-13  2020-03-10

# %%
dividend_df.to_sql(name='dividend_df', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the price_data_df table

# %%
pd.read_sql_query('select * from price_data_df', con=engine).head()
# Out:
#   symbol              company   price      low     high  previous_close  \
# 0    AXP  American Express Co   89.83   89.125   91.430           89.83
# 1   AAPL            Apple Inc  316.85  315.870  320.890          316.85
# 2     BA            Boeing Co  139.00  136.151  144.239          139.00
# 3    CAT      Caterpillar Inc  114.06  113.820  115.680          114.06
# 4   CSCO    Cisco Systems Inc   44.64   44.555   45.655           44.64
#
#    esg_rating
# 0          22
# 1          24
# 2          39
# 3          38
# 4          14

# %% [markdown]
# ### Confirm data has been added by querying the dividend_df table

# %%
pd.read_sql_query('select * from dividend_df', con=engine).head()
# Out:
#   symbol  dividend_yield  annualized_dividend ex_div_date    pay_date
# 0    XOM            7.87                 3.48  2020-05-12  2020-06-10
# 1     BA            6.16                 8.22  2020-02-13  2020-03-06
# 2    CVX            5.40                 5.16  2020-05-18  2020-06-10
# 3    IBM            5.30                 6.52  2020-05-07  2020-06-10
# 4    UTX            5.16                 2.94  2020-02-13  2020-03-10
