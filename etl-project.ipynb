# %% [markdown]
# # ETL of Dow 30 Stock Data
# #### Fabienne Zumbuehl; James Ye; Tanvir Khan

# %%
import pandas as pd
#from bs4 import BeautifulSoup as bs
from splinter import Browser
import time
from sqlalchemy import create_engine
import psycopg2

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## Price data from cnbc.com

# %%
price_url = "https://www.cnbc.com/dow-30/"

# %%
browser.visit(price_url)
time.sleep(5)
price_html = browser.html

# %%
price_data_tables = pd.read_html(price_html)
print("Number of tables: ", len(price_data_tables))
price_data_df = price_data_tables[0]

# drop ticker 'Dow' because their substainability can not be found in Yahoo Finance
price_data_df.drop(index=29, inplace=True)

price_data_df = price_data_df[["SYMBOL","NAME", "PRICE", "LOW", "HIGH", "PREVIOUS CLOSE"]].copy()
price_data_df.rename(columns = {"SYMBOL":"symbol","NAME":"company", "PRICE":"price", "LOW":"low", "HIGH":"high", "PREVIOUS CLOSE":"previous_close"}, inplace=True)
price_data_df
# Out:
# Number of tables:  1
#    symbol                               company   price     low     high  \
# 0     AXP                   American Express Co   94.32   92.89   95.570
# 1    AAPL                             Apple Inc  316.73  316.50  324.240
# 2      BA                             Boeing Co  144.73  142.61  145.910
# 3     CAT                       Caterpillar Inc  117.41  115.98  118.562
# 4    CSCO                     Cisco Systems Inc   44.84   44.68   45.800
# 5     CVX                          Chevron Corp   93.30   92.03   94.340
# 6     XOM                      Exxon Mobil Corp   45.91   45.47   46.300
# 7      GS               Goldman Sachs Group Inc  196.06  185.22  197.100
# 8      HD                        Home Depot Inc  242.48  242.07  248.220
# 9     IBM  International Business Machines Corp  121.76  121.01  122.620
# 10   INTC                            Intel Corp   62.34   62.12   64.140
# 11    JNJ                     Johnson & Johnson  144.56  144.30  146.440
# 12     KO                          Coca-Cola Co   46.09   45.93   46.930
# 13    JPM                   JPMorgan Chase & Co   95.82   92.61   97.500
# 14    MCD                       McDonald’s Corp  184.84  184.24  190.660
# 15    MMM                                 3M Co  152.08  149.20  152.980
# 16    MRK                        Merck & Co Inc   77.26   76.91   78.600
# 17   MSFT                        Microsoft Corp  181.57  181.10  186.500
# 18    NKE                              Nike Inc   96.62   95.28   97.430
# 19    PFE                            Pfizer Inc   37.49   37.45   37.870
# 20     PG                   Procter & Gamble Co  112.03  111.68  114.150
# 21    TRV               Travelers Companies Inc  103.36  102.73  104.570
# 22    UNH                UnitedHealth Group Inc  294.89  292.50  297.030
# 23    RTX            Raytheon Technologies Corp   64.47   62.36   65.550
# 24     VZ            Verizon Communications Inc   54.30   54.18   55.245
# 25      V                              Visa Inc  193.22  192.76  196.270
# 26    WBA          Walgreens Boots Alliance Inc   42.16   40.34   42.470
# 27    WMT                           Walmart Inc  123.86  123.63  125.510
# 28    DIS                        Walt Disney Co  120.95  120.43  122.505
#
#     previous_close
# 0           89.330
# 1          318.890
# 2          137.530
# 3          112.470
# 4           44.900
# 5           90.280
# 6           44.600
# 7          179.930
# 8          241.880
# 9          118.390
# 10          62.255
# 11         144.370
# 12          45.030
# 13          89.470
# 14         184.410
# 15         146.440
# 16          76.370
# 17         183.510
# 18          93.750
# 19          37.500
# 20         112.600
# 21         100.100
# 22         289.940
# 23          60.000
# 24          54.100
# 25         190.860
# 26          39.600
# 27         124.330
# 28         118.020

# %%
dow29_symbols = price_data_df["symbol"]
type(dow29_symbols)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Dividend data from dividend.com

# %%
dividend_url = "https://www.dividend.com/dividend-stocks/dow-30-dividend-stocks/"

# %%
dividend_data_tables = pd.read_html(dividend_url)
print("Number of tables: ", len(dividend_data_tables))
dividend_data_df = dividend_data_tables[0]
dividend_data_df.head()
# Out:
# Number of tables:  1
#    Unnamed: 0 Stock Symbol         Company Name DARSâ¢ Rating Dividend Yield  \
# 0         NaN          XOM          Exxon Mobil         locked          7.81%
# 1         NaN           BA           Boeing Co.         locked          5.98%
# 2         NaN          CVX         Chevron Corp         locked          5.72%
# 3         NaN          IBM             IBM Corp         locked          5.51%
# 4         NaN          UTX  United Technologies         locked          4.89%
#
#   Closing Price Annualized Dividend Ex-Div Date    Pay Date
# 0        $41.97             $3.4800  2020-05-12  2020-06-10
# 1       $120.57             $8.2200  2020-02-13  2020-03-06
# 2        $89.53             $5.1600  2020-05-18  2020-06-10
# 3       $114.33             $6.5200  2020-05-07  2020-06-10
# 4        $86.01             $2.9400  2020-02-13  2020-03-10

# %%
# only run these once!!!
del(dividend_data_df["Unnamed: 0"])
#dividend_data_df.set_index("Stock Symbol", inplace=True)
dividend_data_df.head()
# Out:
#   Stock Symbol         Company Name DARSâ¢ Rating Dividend Yield  \
# 0          XOM          Exxon Mobil         locked          7.81%
# 1           BA           Boeing Co.         locked          5.98%
# 2          CVX         Chevron Corp         locked          5.72%
# 3          IBM             IBM Corp         locked          5.51%
# 4          UTX  United Technologies         locked          4.89%
#
#   Closing Price Annualized Dividend Ex-Div Date    Pay Date
# 0        $41.97             $3.4800  2020-05-12  2020-06-10
# 1       $120.57             $8.2200  2020-02-13  2020-03-06
# 2        $89.53             $5.1600  2020-05-18  2020-06-10
# 3       $114.33             $6.5200  2020-05-07  2020-06-10
# 4        $86.01             $2.9400  2020-02-13  2020-03-10

# %%
dividend_reduced_df = dividend_data_df[['Stock Symbol', 'Dividend Yield', 'Annualized Dividend', 'Ex-Div Date', 'Pay Date']].copy()
dividend_reduced_df.drop(index=28, inplace=True)
dividend_df = dividend_reduced_df
dividend_df
# Out:
#    Stock Symbol Dividend Yield Annualized Dividend Ex-Div Date    Pay Date
# 0           XOM          7.81%             $3.4800  2020-05-12  2020-06-10
# 1            BA          5.98%             $8.2200  2020-02-13  2020-03-06
# 2           CVX          5.72%             $5.1600  2020-05-18  2020-06-10
# 3           IBM          5.51%             $6.5200  2020-05-07  2020-06-10
# 4           UTX          4.89%             $2.9400  2020-02-13  2020-03-10
# 5           WBA          4.60%             $1.8300  2020-05-19  2020-06-12
# 6           PFE          4.08%             $1.5200  2020-05-07  2020-06-05
# 7           MMM          4.03%             $5.8800  2020-05-21  2020-06-12
# 8           JPM          3.99%             $3.6000  2020-07-02  2020-07-31
# 9           CAT          3.66%             $4.1200  2020-04-17  2020-05-20
# 10           KO          3.63%             $1.6400  2020-06-12  2020-07-01
# 11          TRV          3.43%             $3.4000  2020-06-09  2020-06-30
# 12         CSCO          3.21%             $1.4400  2020-04-02  2020-04-22
# 13          MRK          3.19%             $2.4400  2020-03-13  2020-04-07
# 14           PG          2.83%             $3.1628  2020-04-23  2020-05-15
# 15           GS          2.78%             $5.0000  2020-05-29  2020-06-29
# 16          JNJ          2.75%             $4.0400  2020-05-22  2020-06-09
# 17          MCD          2.70%             $5.0000  2020-05-29  2020-06-15
# 18           HD          2.48%             $6.0000  2020-06-03  2020-06-18
# 19         INTC          2.12%             $1.3200  2020-05-06  2020-06-01
# 20          AXP          1.93%             $1.7200  2020-07-01  2020-08-10
# 21          WMT          1.73%             $2.1600  2020-08-13  2020-09-08
# 22          UNH          1.51%             $4.3200  2020-03-13  2020-03-24
# 23          DIS          1.49%             $1.7600  2019-12-13  2020-01-16
# 24         MSFT          1.11%             $2.0400  2020-05-20  2020-06-11
# 25          NKE          1.04%             $0.9800  2020-05-29  2020-07-01
# 26         AAPL          1.03%             $3.2800  2020-05-08  2020-05-14
# 27            V          0.63%             $1.2000  2020-05-13  2020-06-02

# %%
dividend_df['Dividend Yield'] = dividend_df['Dividend Yield'].str.replace('%','').astype(float)
dividend_df['Annualized Dividend'] = dividend_df['Annualized Dividend'].str.replace('$','').astype(float)

# %%
print(dividend_df.dtypes)

dividend_df.rename(columns = {"Stock Symbol":"symbol", "Dividend Yield": "dividend_yield", "Annualized Dividend":"annualized_dividend", "Ex-Div Date":"ex_div_date", "Pay Date":"pay_date"}, inplace=True)


dividend_df.head()
# Out:
# Stock Symbol            object
# Dividend Yield         float64
# Annualized Dividend    float64
# Ex-Div Date             object
# Pay Date                object
# dtype: object
#   symbol  dividend_yield  annualized_dividend ex_div_date    pay_date
# 0    XOM            7.81                 3.48  2020-05-12  2020-06-10
# 1     BA            5.98                 8.22  2020-02-13  2020-03-06
# 2    CVX            5.72                 5.16  2020-05-18  2020-06-10
# 3    IBM            5.51                 6.52  2020-05-07  2020-06-10
# 4    UTX            4.89                 2.94  2020-02-13  2020-03-10

# %% [markdown]
# ## ESG Rating data from finance.yahoo.com

# %%
print("ticker", "ESG Score")
egs_rating_list = []
first = True
for stock_symbol in dow29_symbols:
    sustainability_url = f"https://finance.yahoo.com/quote/{stock_symbol}/sustainability?p={stock_symbol}"
    browser.visit(sustainability_url)
    if first:
        time.sleep(5)
        first = False
    else:
        time.sleep(1)
    ESG_Risk_Score = browser.find_by_css('div[class="Fz(36px) Fw(600) D(ib) Mend(5px)"]').value
    print(stock_symbol, ESG_Risk_Score)
    egs_rating_list.append(ESG_Risk_Score)
# Out:
# ticker ESG Score
# AXP 22
# AAPL 24
# BA 39
# CAT 38
# CSCO 14
# CVX 40
# XOM 34
# GS 32
# HD 13
# IBM 18
# INTC 16
# JNJ 35
# KO 26
# JPM 22
# MCD 25
# MMM 34
# MRK 28
# MSFT 16
# NKE 17
# PFE 33
# PG 25
# TRV 24
# UNH 21
# RTX 29
# VZ 20
# V 18
# WBA 17
# WMT 29
# DIS 15

# %%
egs_rating_list
# Out:
# ['22',
#  '24',
#  '39',
#  '38',
#  '14',
#  '40',
#  '34',
#  '32',
#  '13',
#  '18',
#  '16',
#  '35',
#  '26',
#  '22',
#  '25',
#  '34',
#  '28',
#  '16',
#  '17',
#  '33',
#  '25',
#  '24',
#  '21',
#  '29',
#  '20',
#  '18',
#  '17',
#  '29',
#  '15']

# %%
price_data_df['esg_rating'] = egs_rating_list

# %%
price_data_df['esg_rating'] = pd.to_numeric(price_data_df['esg_rating'])
price_data_df.dtypes
# Out:
# symbol             object
# company            object
# price             float64
# low               float64
# high              float64
# previous_close    float64
# esg_rating          int64
# dtype: object

# %%
price_data_df
# Out:
#    symbol                               company   price     low     high  \
# 0     AXP                   American Express Co   94.32   92.89   95.570
# 1    AAPL                             Apple Inc  316.73  316.50  324.240
# 2      BA                             Boeing Co  144.73  142.61  145.910
# 3     CAT                       Caterpillar Inc  117.41  115.98  118.562
# 4    CSCO                     Cisco Systems Inc   44.84   44.68   45.800
# 5     CVX                          Chevron Corp   93.30   92.03   94.340
# 6     XOM                      Exxon Mobil Corp   45.91   45.47   46.300
# 7      GS               Goldman Sachs Group Inc  196.06  185.22  197.100
# 8      HD                        Home Depot Inc  242.48  242.07  248.220
# 9     IBM  International Business Machines Corp  121.76  121.01  122.620
# 10   INTC                            Intel Corp   62.34   62.12   64.140
# 11    JNJ                     Johnson & Johnson  144.56  144.30  146.440
# 12     KO                          Coca-Cola Co   46.09   45.93   46.930
# 13    JPM                   JPMorgan Chase & Co   95.82   92.61   97.500
# 14    MCD                       McDonald’s Corp  184.84  184.24  190.660
# 15    MMM                                 3M Co  152.08  149.20  152.980
# 16    MRK                        Merck & Co Inc   77.26   76.91   78.600
# 17   MSFT                        Microsoft Corp  181.57  181.10  186.500
# 18    NKE                              Nike Inc   96.62   95.28   97.430
# 19    PFE                            Pfizer Inc   37.49   37.45   37.870
# 20     PG                   Procter & Gamble Co  112.03  111.68  114.150
# 21    TRV               Travelers Companies Inc  103.36  102.73  104.570
# 22    UNH                UnitedHealth Group Inc  294.89  292.50  297.030
# 23    RTX            Raytheon Technologies Corp   64.47   62.36   65.550
# 24     VZ            Verizon Communications Inc   54.30   54.18   55.245
# 25      V                              Visa Inc  193.22  192.76  196.270
# 26    WBA          Walgreens Boots Alliance Inc   42.16   40.34   42.470
# 27    WMT                           Walmart Inc  123.86  123.63  125.510
# 28    DIS                        Walt Disney Co  120.95  120.43  122.505
#
#     previous_close  esg_rating
# 0           89.330          22
# 1          318.890          24
# 2          137.530          39
# 3          112.470          38
# 4           44.900          14
# 5           90.280          40
# 6           44.600          34
# 7          179.930          32
# 8          241.880          13
# 9          118.390          18
# 10          62.255          16
# 11         144.370          35
# 12          45.030          26
# 13          89.470          22
# 14         184.410          25
# 15         146.440          34
# 16          76.370          28
# 17         183.510          16
# 18          93.750          17
# 19          37.500          33
# 20         112.600          25
# 21         100.100          24
# 22         289.940          21
# 23          60.000          29
# 24          54.100          20
# 25         190.860          18
# 26          39.600          17
# 27         124.330          29
# 28         118.020          15

# %% [markdown]
# # Load data into Postgres database

# %%
# Creating connection with database
# stock_db is database created in PGAdmin
connection_string = "postgres:postgres@localhost:5432/stock_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['price_data_df', 'dividend_df']

# %%
print(price_data_df.dtypes)

price_data_df.head()
# Out:
# symbol             object
# company            object
# price             float64
# low               float64
# high              float64
# previous_close    float64
# esg_rating          int64
# dtype: object
#   symbol              company   price     low     high  previous_close  \
# 0    AXP  American Express Co   94.32   92.89   95.570           89.33
# 1   AAPL            Apple Inc  316.73  316.50  324.240          318.89
# 2     BA            Boeing Co  144.73  142.61  145.910          137.53
# 3    CAT      Caterpillar Inc  117.41  115.98  118.562          112.47
# 4   CSCO    Cisco Systems Inc   44.84   44.68   45.800           44.90
#
#    esg_rating
# 0          22
# 1          24
# 2          39
# 3          38
# 4          14

# %%
price_data_df.to_sql(name='price_data_df', con=engine, if_exists='replace', index=False)
# if_exists='replace' instead of append method if table already have a data

# %%
print(dividend_df.dtypes)

dividend_df.head()
# Out:
# symbol                  object
# dividend_yield         float64
# annualized_dividend    float64
# ex_div_date             object
# pay_date                object
# dtype: object
#   symbol  dividend_yield  annualized_dividend ex_div_date    pay_date
# 0    XOM            7.81                 3.48  2020-05-12  2020-06-10
# 1     BA            5.98                 8.22  2020-02-13  2020-03-06
# 2    CVX            5.72                 5.16  2020-05-18  2020-06-10
# 3    IBM            5.51                 6.52  2020-05-07  2020-06-10
# 4    UTX            4.89                 2.94  2020-02-13  2020-03-10

# %%
dividend_df.to_sql(name='dividend_df', con=engine, if_exists='replace', index=False)
# if_exists='replace' if table already have a data

# %% [markdown]
# ### Confirm data has been added by querying the price_data_df table

# %%
pd.read_sql_query('select * from price_data_df ORDER BY symbol ASC', con=engine)
# Out:
#    symbol                               company   price     low     high  \
# 0    AAPL                             Apple Inc  316.73  316.50  324.240
# 1     AXP                   American Express Co   94.32   92.89   95.570
# 2      BA                             Boeing Co  144.73  142.61  145.910
# 3     CAT                       Caterpillar Inc  117.41  115.98  118.562
# 4    CSCO                     Cisco Systems Inc   44.84   44.68   45.800
# 5     CVX                          Chevron Corp   93.30   92.03   94.340
# 6     DIS                        Walt Disney Co  120.95  120.43  122.505
# 7      GS               Goldman Sachs Group Inc  196.06  185.22  197.100
# 8      HD                        Home Depot Inc  242.48  242.07  248.220
# 9     IBM  International Business Machines Corp  121.76  121.01  122.620
# 10   INTC                            Intel Corp   62.34   62.12   64.140
# 11    JNJ                     Johnson & Johnson  144.56  144.30  146.440
# 12    JPM                   JPMorgan Chase & Co   95.82   92.61   97.500
# 13     KO                          Coca-Cola Co   46.09   45.93   46.930
# 14    MCD                       McDonald’s Corp  184.84  184.24  190.660
# 15    MMM                                 3M Co  152.08  149.20  152.980
# 16    MRK                        Merck & Co Inc   77.26   76.91   78.600
# 17   MSFT                        Microsoft Corp  181.57  181.10  186.500
# 18    NKE                              Nike Inc   96.62   95.28   97.430
# 19    PFE                            Pfizer Inc   37.49   37.45   37.870
# 20     PG                   Procter & Gamble Co  112.03  111.68  114.150
# 21    RTX            Raytheon Technologies Corp   64.47   62.36   65.550
# 22    TRV               Travelers Companies Inc  103.36  102.73  104.570
# 23    UNH                UnitedHealth Group Inc  294.89  292.50  297.030
# 24      V                              Visa Inc  193.22  192.76  196.270
# 25     VZ            Verizon Communications Inc   54.30   54.18   55.245
# 26    WBA          Walgreens Boots Alliance Inc   42.16   40.34   42.470
# 27    WMT                           Walmart Inc  123.86  123.63  125.510
# 28    XOM                      Exxon Mobil Corp   45.91   45.47   46.300
#
#     previous_close  esg_rating
# 0          318.890          24
# 1           89.330          22
# 2          137.530          39
# 3          112.470          38
# 4           44.900          14
# 5           90.280          40
# 6          118.020          15
# 7          179.930          32
# 8          241.880          13
# 9          118.390          18
# 10          62.255          16
# 11         144.370          35
# 12          89.470          22
# 13          45.030          26
# 14         184.410          25
# 15         146.440          34
# 16          76.370          28
# 17         183.510          16
# 18          93.750          17
# 19          37.500          33
# 20         112.600          25
# 21          60.000          29
# 22         100.100          24
# 23         289.940          21
# 24         190.860          18
# 25          54.100          20
# 26          39.600          17
# 27         124.330          29
# 28          44.600          34

# %% [markdown]
# ### Confirm data has been added by querying the dividend_df table
# #### UTX  is not in the price_data_df whereas VZ, RTX, are not in the dividend_df

# %%
pd.read_sql_query('select * from dividend_df ORDER BY symbol ASC', con=engine)
# Out:
#    symbol  dividend_yield  annualized_dividend ex_div_date    pay_date
# 0    AAPL            1.03               3.2800  2020-05-08  2020-05-14
# 1     AXP            1.93               1.7200  2020-07-01  2020-08-10
# 2      BA            5.98               8.2200  2020-02-13  2020-03-06
# 3     CAT            3.66               4.1200  2020-04-17  2020-05-20
# 4    CSCO            3.21               1.4400  2020-04-02  2020-04-22
# 5     CVX            5.72               5.1600  2020-05-18  2020-06-10
# 6     DIS            1.49               1.7600  2019-12-13  2020-01-16
# 7      GS            2.78               5.0000  2020-05-29  2020-06-29
# 8      HD            2.48               6.0000  2020-06-03  2020-06-18
# 9     IBM            5.51               6.5200  2020-05-07  2020-06-10
# 10   INTC            2.12               1.3200  2020-05-06  2020-06-01
# 11    JNJ            2.75               4.0400  2020-05-22  2020-06-09
# 12    JPM            3.99               3.6000  2020-07-02  2020-07-31
# 13     KO            3.63               1.6400  2020-06-12  2020-07-01
# 14    MCD            2.70               5.0000  2020-05-29  2020-06-15
# 15    MMM            4.03               5.8800  2020-05-21  2020-06-12
# 16    MRK            3.19               2.4400  2020-03-13  2020-04-07
# 17   MSFT            1.11               2.0400  2020-05-20  2020-06-11
# 18    NKE            1.04               0.9800  2020-05-29  2020-07-01
# 19    PFE            4.08               1.5200  2020-05-07  2020-06-05
# 20     PG            2.83               3.1628  2020-04-23  2020-05-15
# 21    TRV            3.43               3.4000  2020-06-09  2020-06-30
# 22    UNH            1.51               4.3200  2020-03-13  2020-03-24
# 23    UTX            4.89               2.9400  2020-02-13  2020-03-10
# 24      V            0.63               1.2000  2020-05-13  2020-06-02
# 25    WBA            4.60               1.8300  2020-05-19  2020-06-12
# 26    WMT            1.73               2.1600  2020-08-13  2020-09-08
# 27    XOM            7.81               3.4800  2020-05-12  2020-06-10

# %% [markdown]
# ### Joining both tables on "Symbol" column outputs final CSV file

# %%
final_dow_data = pd.merge(price_data_df, dividend_df, on='symbol', how='inner')
final_dow_data
# Out:
#    symbol                               company   price     low     high  \
# 0     AXP                   American Express Co   94.32   92.89   95.570
# 1    AAPL                             Apple Inc  316.73  316.50  324.240
# 2      BA                             Boeing Co  144.73  142.61  145.910
# 3     CAT                       Caterpillar Inc  117.41  115.98  118.562
# 4    CSCO                     Cisco Systems Inc   44.84   44.68   45.800
# 5     CVX                          Chevron Corp   93.30   92.03   94.340
# 6     XOM                      Exxon Mobil Corp   45.91   45.47   46.300
# 7      GS               Goldman Sachs Group Inc  196.06  185.22  197.100
# 8      HD                        Home Depot Inc  242.48  242.07  248.220
# 9     IBM  International Business Machines Corp  121.76  121.01  122.620
# 10   INTC                            Intel Corp   62.34   62.12   64.140
# 11    JNJ                     Johnson & Johnson  144.56  144.30  146.440
# 12     KO                          Coca-Cola Co   46.09   45.93   46.930
# 13    JPM                   JPMorgan Chase & Co   95.82   92.61   97.500
# 14    MCD                       McDonald’s Corp  184.84  184.24  190.660
# 15    MMM                                 3M Co  152.08  149.20  152.980
# 16    MRK                        Merck & Co Inc   77.26   76.91   78.600
# 17   MSFT                        Microsoft Corp  181.57  181.10  186.500
# 18    NKE                              Nike Inc   96.62   95.28   97.430
# 19    PFE                            Pfizer Inc   37.49   37.45   37.870
# 20     PG                   Procter & Gamble Co  112.03  111.68  114.150
# 21    TRV               Travelers Companies Inc  103.36  102.73  104.570
# 22    UNH                UnitedHealth Group Inc  294.89  292.50  297.030
# 23      V                              Visa Inc  193.22  192.76  196.270
# 24    WBA          Walgreens Boots Alliance Inc   42.16   40.34   42.470
# 25    WMT                           Walmart Inc  123.86  123.63  125.510
# 26    DIS                        Walt Disney Co  120.95  120.43  122.505
#
#     previous_close  esg_rating  dividend_yield  annualized_dividend  \
